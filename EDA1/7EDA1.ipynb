# %% [markdown]
# # 1. Data Cleaning and Preparation

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df =pd.read_csv('Cardiotocographic.csv')
df
# Out:
#               LB        AC        FM        UC        DL   DS   DP  ASTV  \
# 0     120.000000  0.000000  0.000000  0.000000  0.000000  0.0  0.0  73.0
# 1     132.000000  0.006380  0.000000  0.006380  0.003190  0.0  0.0  17.0
# 2     133.000000  0.003322  0.000000  0.008306  0.003322  0.0  0.0  16.0
# 3     134.000000  0.002561  0.000000  0.007742  0.002561  0.0  0.0  16.0
# 4     131.948232  0.006515  0.000000  0.008143  0.000000  0.0  0.0  16.0
# ...          ...       ...       ...       ...       ...  ...  ...   ...
# 2121  140.000000  0.000000  0.961268  0.007426  0.000000  0.0  0.0  79.0
# 2122  140.000000  0.000775  0.000000  0.006979  0.000000  0.0  0.0  78.0
# 2123  140.000000  0.000980  0.000000  0.006863  0.000000  0.0  0.0  79.0
# 2124  140.000000  0.000679  0.000000  0.006110  0.000000  0.0  0.0  78.0
# 2125  142.000000  0.001616 -0.000188  0.008078  0.000000  0.0  0.0  74.0
#
#       MSTV       ALTV  MLTV  Width  Tendency       NSP
# ...

# %%
df.describe()
# Out:
#                 LB           AC           FM           UC           DL  \
# count  2105.000000  2106.000000  2126.000000  2126.000000  2126.000000
# mean    133.343598     0.003219     0.009894     0.004391     0.001895
# std      11.270154     0.004391     0.067540     0.003340     0.003343
# min      51.842487    -0.019284    -0.480634    -0.014925    -0.015393
# 25%     126.000000     0.000000     0.000000     0.001851     0.000000
# 50%     133.000000     0.001634     0.000000     0.004484     0.000000
# 75%     140.000000     0.005650     0.002567     0.006536     0.003289
# max     214.000000     0.038567     0.961268     0.030002     0.030769
#
#                 DS           DP         ASTV         MSTV         ALTV  \
# count  2105.000000  2105.000000  2126.000000  2126.000000  2126.000000
# mean      0.000003     0.000175    46.995984     1.364378    10.285964
# std       0.000142     0.000840    18.813973     1.173632    21.205041
# ...

# %%
df.dtypes
# Out:
# LB          float64
# AC          float64
# FM          float64
# UC          float64
# DL          float64
# DS          float64
# DP          float64
# ASTV        float64
# MSTV        float64
# ALTV        float64
# MLTV        float64
# Width       float64
# Tendency    float64
# NSP         float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2126 entries, 0 to 2125
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   LB        2105 non-null   float64
#  1   AC        2106 non-null   float64
#  2   FM        2126 non-null   float64
#  3   UC        2126 non-null   float64
#  4   DL        2126 non-null   float64
#  5   DS        2105 non-null   float64
#  6   DP        2105 non-null   float64
#  7   ASTV      2126 non-null   float64
#  8   MSTV      2126 non-null   float64
#  9   ALTV      2126 non-null   float64
#  10  MLTV      2105 non-null   float64
#  11  Width     2105 non-null   float64
#  12  Tendency  2105 non-null   float64
#  13  NSP       2105 non-null   float64
# dtypes: float64(14)
# memory usage: 232.7 KB

# %%
df.isna().sum()
# Out:
# LB          21
# AC          20
# FM           0
# UC           0
# DL           0
# DS          21
# DP          21
# ASTV         0
# MSTV         0
# ALTV         0
# MLTV        21
# Width       21
# Tendency    21
# NSP         21
# dtype: int64

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 2121    False
# 2122    False
# 2123    False
# 2124    False
# 2125    False
# Length: 2126, dtype: bool

# %%
df.duplicated().sum()
# Out:
# 2

# %%
df=df.drop_duplicates()

# %%
for i in df.isna().sum():
    print(round(i/len(df)*100,2),'%')
# Out:
# 0.99 %
# 0.94 %
# 0.0 %
# 0.0 %
# 0.0 %
# 0.99 %
# 0.99 %
# 0.0 %
# 0.0 %
# 0.0 %
# 0.99 %
# 0.99 %
# 0.99 %
# 0.99 %

# %%
 df.dropna(inplace=True)
# Out:
# C:\Users\Hi\AppData\Local\Temp\ipykernel_10456\1740178193.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.dropna(inplace=True)

# %%
# Step 5: Detect and treat outliers using IQR method
numerical_columns = df.select_dtypes(include=[np.number]).columns

for col in numerical_columns:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    outliers = ((df[col] < lower_bound) | (df[col] > upper_bound)).sum()
    print(f"Outliers in {col}: {outliers}")
# Out:
# Outliers in LB: 10
# Outliers in AC: 39
# Outliers in FM: 343
# Outliers in UC: 13
# Outliers in DL: 124
# Outliers in DS: 120
# Outliers in DP: 284
# Outliers in ASTV: 10
# Outliers in MSTV: 78
# Outliers in ALTV: 317
# Outliers in MLTV: 81
# Outliers in Width: 10
# Outliers in Tendency: 10
# Outliers in NSP: 559

# %% [markdown]
# # 2. Statistical Summary

# %%
# Statistical summary of the dataset
summary = df.describe()

# Add median and IQR to the summary
summary.loc['median'] = df.median()
Q1 = df.quantile(0.25)
Q3 = df.quantile(0.75)
IQR = Q3 - Q1
summary.loc['IQR'] = IQR

# Display the summary
print("\nStatistical Summary:")
print(summary)
# Out:
# Statistical Summary:
#                  LB           AC           FM           UC           DL  \
# count   2103.000000  2103.000000  2103.000000  2103.000000  2103.000000
# mean     133.342023     0.003203     0.009973     0.004391     0.001894
# std       11.268266     0.004325     0.067902     0.003350     0.003349
# min       51.842487    -0.019284    -0.480634    -0.014925    -0.015393
# 25%      126.000000     0.000000     0.000000     0.001838     0.000000
# 50%      133.000000     0.001631     0.000000     0.004484     0.000000
# 75%      140.000000     0.005650     0.002559     0.006543     0.003295
# max      214.000000     0.038567     0.961268     0.030002     0.030769
# median   133.000000     0.001631     0.000000     0.004484     0.000000
# IQR       14.000000     0.005650     0.002559     0.004705     0.003295
#
#                  DS           DP         ASTV         MSTV         ALTV  \
# count   2103.000000  2103.000000  2103.000000  2103.000000  2103.000000
# ...

# %% [markdown]
# # 3. Data Visualization

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Step 1: Visualize distributions of numerical variables
for col in numerical_columns:
    plt.figure(figsize=(6, 4))
    sns.histplot(df[col], kde=True, color='blue')
    plt.title(f"Distribution of {col}")
    plt.show()

# %%
# Step 2: Boxplots for outlier detection
for col in numerical_columns:
    plt.figure(figsize=(6, 4))
    sns.boxplot(x=df[col])
    plt.title(f"Boxplot of {col}")
    plt.show()

# %%
# Step 3: Correlation heatmap
plt.figure(figsize=(12, 8))
correlation_matrix = df.corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title("Correlation Heatmap")
plt.show()

# %%
# Step 4: Pair plot for all numerical variables
sns.pairplot(df[numerical_columns])
plt.show()

# %%
# Step 5: Violin plot for a specific feature
plt.figure(figsize=(8, 6))
sns.violinplot(x='ASTV', y='LB', data=df)
plt.title("Violin Plot: ASTV vs LB")
plt.show()

# %% [markdown]
# # 4. Pattern Recognition and Insights

# %%
# Step 1: Identify highly correlated features
high_correlation = correlation_matrix.abs().unstack().sort_values(ascending=False)
high_correlation = high_correlation[high_correlation < 1]  # Exclude self-correlation
print("\nTop Correlations Between Variables:")
print(high_correlation.head(10))
# Out:
# Top Correlations Between Variables:
# Width  MSTV     0.435563
# MSTV   Width    0.435563
# NSP    ASTV     0.422515
# ASTV   NSP      0.422515
# MSTV   DL       0.410270
# DL     MSTV     0.410270
# Width  DL       0.409793
# DL     Width    0.409793
# NSP    ALTV     0.365708
# ALTV   NSP      0.365708
# dtype: float64

# %%
# Step 2: Scatter plot for top correlated variables
plt.figure(figsize=(8, 6))
sns.scatterplot(x='LB', y='UC', data=df)
plt.title("Scatter Plot: LB vs UC")
plt.xlabel('Baseline FHR (LB)')
plt.ylabel('Uterine Contractions (UC)')
plt.show()

# %% [markdown]
# # 5. Conclusion:

# %%
correlation_matrix = df.corr()

# %%
plt.figure(figsize=(12, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title("Correlation Heatmap")
plt.show()
